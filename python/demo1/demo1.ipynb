# %%
import numpy as np
import matplotlib.pyplot as mp
d=np.array([45,32,17,28,33,26])
print(d)
print(d[:-1])
print(np.diff(d))
returns=np.diff(d)/d[:-1]
print(returns)
print(np.mean(returns),'+-',np.std(returns))
mp.clf()
mp.plot([0,1],[0,2])
mp.show()
# Out:
# [45 32 17 28 33 26]
# [45 32 17 28 33]
# [-13 -15  11   5  -7]
# [-0.28888889 -0.46875     0.64705882  0.17857143 -0.21212121]
# -0.0288259697819 +- 0.398646950269

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x**2)

plt.clf()
plt.figure(figsize=(8,4))
plt.plot(x,y,label="$sin(x)$",color="red",linewidth=2)
plt.plot(x,z,"b--",label="$cos(x^2)$")
plt.xlabel("Time(s)")
plt.ylabel("Volt")
plt.title("PyPlot First Example")
plt.ylim(-1.2,1.2)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as mp
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)
#print(y)
mp.clf()
mp.xlabel('x')
mp.ylabel('sin(x)')
mp.plot(x,y,label='$sin(x)$',linewidth=2)
mp.legend()
mp.show()

# %%
import time
import numpy as np
import math

x=np.linspace(0, 1000000, 1)
start=time.clock()
np.sin(x,x)
print('delta=',time.clock()-start)

start=time.clock()
for i,t in enumerate(x):
    y=math.sin(x[i])
print('delta=',time.clock()-start)
# Out:
# delta= 0.00011800000000050659
# delta= 0.00025000000000030553

# %%
import time
import math
import numpy as np

x=[i*0.001 for i in range(1000000)]
start=time.clock()
y=[]
for i,t in enumerate(x):
    y.append(math.sin(t))
print('delta=',time.clock()-start)
# Out:
# delta= 0.31664700000000057

# %%
import numpy as np
x=np.array([4,8,12,20])
y=np.array([3,5,6,7])
print(x/y)
print(x//y)
# Out:
# [ 1.33333333  1.6         2.          2.85714286]
# [1 1 2 2]

# %%
import numpy as np
import matplotlib.pyplot as mp

def triangle_wave(c,c0,hc):
    def _fun(x):
        x=x-int(x)
        if x>=c : r=0.0
        elif x<c0 : r=x/c0*hc
        else: r=(c-x)/(c-c0)*hc
        return r
    
    return np.frompyfunc(_fun, 1, 1)

x=np.linspace(0,2,1000)
y=triangle_wave(0.6, 0.4, 1.0)(x)
y.astype(np.float64)
mp.clf()
mp.plot(x,y)
mp.show()

# %%
import mayavi.mlab as ml
import numpy as np
x,y=np.ogrid[-2:2:20j, -2:2:20j]
z=x*np.exp(-x**2-y**2)
pl=ml.surf(x,y,z)
ml.axes(xlabel='x',ylabel='y',zlabel='z')
ml.outline(pl)

# %%
# Create the data.
from numpy import pi, sin, cos, mgrid
dphi, dtheta = pi/250.0, pi/250.0
[phi,theta] = mgrid[0:pi+dphi*1.5:dphi,0:2*pi+dtheta*1.5:dtheta]
m0 = 4; m1 = 3; m2 = 2; m3 = 3; m4 = 6; m5 = 2; m6 = 6; m7 = 4;
r = sin(m0*phi)**m1 + cos(m2*phi)**m3 + sin(m4*theta)**m5 + cos(m6*theta)**m7
x = r*sin(phi)*cos(theta)
y = r*cos(phi)
z = r*sin(phi)*sin(theta)

# View it.
from mayavi import mlab
s = mlab.mesh(x, y, z)
mlab.show()

# %%
from mayavi import mlab
s=[10,20,25,31,55]
mlab.barchart(s)
